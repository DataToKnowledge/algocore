# %%
http://newspaper.readthedocs.org/en/latest/user_guide/quickstart.html#performing-nlp-on-an-article

# %%
import newspaper

# %%
repubblica = newspaper.build('http://www.repubblica.it/',language='it')
# Out:
# CRITICAL:newspaper.network:[REQUEST FAILED] HTTPConnectionPool(host='fantavillage.repubblica.it', port=80): Read timed out. (read timeout=7)
# CRITICAL:newspaper.network:[REQUEST FAILED] HTTPConnectionPool(host='reporter.repubblica.it', port=80): Max retries exceeded with url: / (Caused by <class 'socket.gaierror'>: [Errno 8] nodename nor servname provided, or not known)

# %%
for a in repubblica.articles:
    print(a.url)
# Out:
# http://www.repubblica.it/viaggi/2014/06/22/news/langhe_monferrato_e_roero_nell_unesco-117052332/
# http://torino.repubblica.it/cronaca/2016/02/27/news/_amore_e_ginnastica_una_frasson_amazzone_straordinaria_malgrado_la_musica_-134373432/
# http://richiamo-della-foresta.blogautore.repubblica.it/2016/02/19/renzi-galleggia-sulla-vita-degli-animali/
# http://temi.repubblica.it/iniziative-biblioteca/2015/12/11/il-cinema-di-pasolini/
# http://torino.repubblica.it/cronaca/2016/02/27/news/una_decina_di_coperti_e_specialita_africane_ma_il_ristorante_e_abusivo-134378447/#commenta
# http://napoli.repubblica.it/cronaca/2016/02/27/foto/fotografia_l_hobby_dei_vip_negli_scatti_di_fernando_alfieri-134340360/1/
# http://www.repubblica.it/esteri/elezioni-usa/primarie2016/2016/02/28/news/primarie_2016_trump_cita_mussolini-134432576/
# http://bologna.repubblica.it/cronaca/2016/02/27/news/_dislessico_non_pigro_bologna_il_tar_promuove_lo_studente_e_sconfessa_i_prof-134355458/
# ...

# %%
repubblica.size()
# Out:
# 2362

# %%
for c in repubblica.category_urls():
    print(c)
# Out:
# http://www.repubblica.it/
# http://borgomeo.blogautore.repubblica.it
# http://roma.repubblica.it
# http://video.repubblica.it
# http://viaggi.repubblica.it
# http://torino.repubblica.it
# https://notifiche.repubblica.it
# http://assante.blogautore.repubblica.it
# http://sport.repubblica.it
# http://napoli.repubblica.it
# http://iniziative.editoriali.repubblica.it
# http://bocca.blogautore.repubblica.it
# http://d.repubblica.it
# http://firenze.repubblica.it
# http://palermo.repubblica.it
# http://micromega.repubblica.it
# http://genova.repubblica.it
# http://granello.blogautore.repubblica.it
# http://meteo.repubblica.it
# http://velvet.repubblica.it
# http://temi.repubblica.it
# http://scuola.repubblica.it
# http://milano.repubblica.it
# http://inchieste.repubblica.it
# http://fantavillage.repubblica.it
# http://richiamo-della-foresta.blogautore.repubblica.it
# http://www.repubblica.it
# http://trovacinema.repubblica.it
# http://clericetti.blogautore.repubblica.it
# ...

# %%
for f in repubblica.feed_urls():
    print(f)
# Out:
# http://clericetti.blogautore.repubblica.it/feed/
# http://bocca.blogautore.repubblica.it/wp-content/plugins/nextgen-gallery/products/photocrati_nextgen/modules/ngglegacy/xml/media-rss.php
# http://milano.repubblica.it/rss/rss2.0.xml
# http://www.repubblica.it/rss/sport/rss2.0.xml
# http://granello.blogautore.repubblica.it/feed/
# http://borgomeo.blogautore.repubblica.it/feed/
# http://richiamo-della-foresta.blogautore.repubblica.it/comments/feed/
# http://temi.repubblica.it/micromega-online/feed/
# http://xl.repubblica.it/feed/
# http://genova.repubblica.it/rss/rss2.0.xml
# http://assante.blogautore.repubblica.it/feed/
# http://richiamo-della-foresta.blogautore.repubblica.it/feed/
# http://torino.repubblica.it/rss/rss2.0.xml
# http://www.repubblica.it/rss/homepage/rss2.0.xml
# http://xl.repubblica.it/comments/feed/
# http://bologna.repubblica.it/rss/rss2.0.xml
# http://xl.repubblica.it/homepage/feed/
# http://napoli.repubblica.it/rss/rss2.0.xml
# ...

# %%
repubblica.brand
# Out:
# 'repubblica'

# %%
article = repubblica.articles[0]

# %%
article.download()

# %%
article.parse()

# %%
article.title
# Out:
# u'http://kpm.data.kataweb.it/kpmimages/kpm2/misc/2014/06/22/118950.jpeg'

# %%
article.text
# Out:
# u'Ce l\'ha fatta. E senza patemi. L\'area italiana candidata, l\'unica del 2014, ha ottenuto dopo un esame-lampo l\'iscrizione al Patrimonio dell\'Umanit\xe0 Unesco. I paesaggi vitivinicoli delle Langhe, del Roero e del Monferrato, nel Basso Piemonte, \xe8 entrato nella Lista World Heritage. E\' il 50mo sito italiano, il che permette al nostro Paese di conservare la leadership nella classifica per nazioni, seppure con la Cina - che ha ridotto le distanze a 3 sole lunghezze, grazie a 2 new entry. L\'ingresso \xe8 avvenuto letteralmente per acclamazione, con il delegato tedesco primo a complimentarsi con il Piemonte e con l\'Italia "campione del mondo" in questa particolare classifica, e il solo delegato croato a chiedere - tra il serio e il faceto - al delegato piemontese una descrizione dei vini. Arrivata la quale (sotto forma di enunciazione delle parole "barolo", "barbera", "spumante"...) la decisione \xe8 arrivata a tempo di record, con il sorriso benevolo della chairman (la sedut
# ...

# %%
article.top_image
# Out:
# u'http://kpm.data.kataweb.it/kpmimages/kpm2/misc/2014/06/22/118950.jpeg'

# %%
article.authors
# Out:
# []

# %%
article.images
# Out:
# [u'http://gruppoespresso01.webtrekk.net/253822047730481/wt.pl?p=321,0&cg1=repubblica&cg2=noscript',
#  u'http://kpm.data.kataweb.it/kpmimages/kpm2/misc/2014/06/22/118950.jpeg',
#  u'http://www.repstatic.it/content/nazionale/img/2016/02/23/123430533-d8adfa2a-9a6c-44bd-a5b1-3834b6a55d85.jpg',
#  u'http://www.repstatic.it/cless/main/nazionale/2013-v1/img/common/repubblica-logo-small.svg',
#  u'http://secure-it.imrworldwide.com/cgi-bin/m?ci=kataweb-it&cg=0&cc=0&ts=noscript',
#  u'http://www.repstatic.it/content/nazionale/img/2016/02/23/123907992-4b4eaf23-04d4-4887-979f-fea3745057cf.jpg',
#  u'http://www.repstatic.it/content/nazionale/img/2016/02/23/122951682-debe59ab-da96-47e3-8735-82fedbc53ff4.jpg']

# %%
article.link_hash
# Out:
# '560bbdaf89d56cb1b4b4bb55956f278a.1456693969.31'

# %%
article.nlp()

# %%
article.summary
# Out:
# u'I paesaggi vitivinicoli delle Langhe, del Roero e del Monferrato, nel Basso Piemonte, \xe8 entrato nella Lista World Heritage.\n"Un riconoscimento - ha commentato il ministro delle Politiche agricole Mauizio Martina - fondamentale per affermare il valore culturale della nostra agricoltura.\nAncora, la fabbrica della seta di Tomioka, in Giappone, e quella olandese di Van Nelle, esempio di architettura industriale dell\'inizio del ventesimo secolo.\nL\'altro Paese che si segnala per il doppio "goal" \xe8 la Turchia, che fa entrare Pergamo e le citt\xe0 di Burza e Cumalizik, le "madri" dell\'Impero Ottomano.\nLa Cina, con due nuove iscrizioni, riduce il divario con il Belpaese, ora \xe8 a meno 3, con 47 siti.'

# %%
article.keywords
# Out:
# [u'roero',
#  u'che',
#  u'nellunesco',
#  u'la',
#  u'monferrato',
#  u'nel',
#  u'langhe',
#  u'dei',
#  u'si',
#  u'del',
#  u'il',
#  u'di',
#  u'delle',
#  u'della']

# %%
newspaper.hot()
# Out:
# [u'Oscars 2016',
#  u'Arsenal',
#  u'Ashley Guindon',
#  u'David Duke',
#  u'Liverpool',
#  u'Tulsi Gabbard',
#  u'Kym Johnson',
#  u'Cheryl Cole',
#  u'Stephen Curry',
#  u'UFC',
#  u'champs',
#  u'Peyton Manning',
#  u'Real Madrid',
#  u'India vs Pakistan',
#  u'Cricinfo',
#  u'UFC Fight Pass',
#  u'KKK',
#  u'Lindsey Vonn',
#  u'Jordan 12',
#  u'Salma Hayek']

# %%
newspaper.popular_urls()
# Out:
# ['http://www.huffingtonpost.com',
#  'http://cnn.com',
#  'http://www.time.com',
#  'http://www.ted.com',
#  'http://pandodaily.com',
#  'http://www.cnbc.com',
#  'http://www.mlb.com',
#  'http://www.pcmag.com',
#  'http://www.foxnews.com',
#  'http://theatlantic.com',
#  'http://www.bbc.co.uk',
#  'http://www.vice.com',
#  'http://www.elle.com',
#  'http://www.vh1.com',
#  'http://espnf1.com',
#  'http://espn.com',
#  'http://www.npr.org',
#  'http://www.sfgate.com',
#  'http://www.glamour.com',
#  'http://www.whosdatedwho.com',
#  'http://kotaku.com',
#  'http://thebostonchannel.com',
#  'http://www.suntimes.com',
#  'http://www.businessinsider.com',
#  'http://www.rivals.com',
#  'http://thebusinessjournal.com',
#  'http://www.newrepublic.com',
#  'http://allthingsd.com',
#  'http://www.topgear.com',
#  'http://thecitizen.com',
#  'http://www.ign.com',
#  'http://www.sci-news.com',
#  'http://www.morningstar.com',
#  'http://www.variety.com',
# ...
